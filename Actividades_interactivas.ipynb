# %% [markdown]
# # Actividades interactivas

# %% [markdown]
# ## Sopa de letras concepto de programacion

# %% [markdown]
# Encuentra las 20 palabras hazlo en el menor tiempo posible para obtener mas puntos.

# %% [markdown]
# [Sopa de letras 1](https://www.educaplay.com/learning-resources/28407555-sopa_de_letras_conceptos_de_programacion.html)

# %% [markdown]
# ### Obtención del sello

# %% [markdown]
# > Escribe en tu cuaderno cuando termines la sopa de letras:
# >
# > - Competencia: 1
# > - Ambito conceptual: Los algoritmos en la vida común y en la programación.
# > - Objetivo: Reconocer conceptos relacionados a la programacion y seleccionarlos para hallar la solución a la sopa de letras
