# %% [markdown]
# ## Clase de Programacion - Linea de Diseño de Software
# ### Profesor: Alexander Acevedo Gómez
# Ingeniero de Sistemas - __Universidad Nacional de Colombia__ <br>
# Magister en Modelado y Simulacion por Computador - __Universidad Jorge Tadeo Lozano__ <br>
# __Telegram: @Alex6m__

# %% [markdown]
# # Taller 1 - Ubicacion por coordenadas en Scratch
# Scratch es un motor de videojuegos, aunque es ampliamente usado en la robotica controlando placas de prototipos como Micro:bit, Arduino, Lego Mindstorms entre otros, su principal característica es el manejo del codigo usando bloques arrastrables, desarrolla las habilidades necesarias para mejorar la logica de programacion.

# %% [markdown]
# ## Entendiendo la Interfaz
# La interfaz se Scratch se divide en tres secciones facilmente identificables:

# %% [markdown]
#  ### Zona de comandos y diseño
#  > Se ubica en el sector izquierdo, los comandos estan agrupados por categorias:
#  >
#  > ![0.PNG](attachment:0.PNG)
#  >
#  > Ademas podemos modificar el disfraz de los personajes y el diseño del escenario

# %% [markdown]
# ### Zona de Desarrollo o programación
# > Donde programan las acciones, rutinas y funcionamiento general de los personajes
# >
# >![2.PNG](attachment:2.PNG)
# > Como se observa, existen cinco maneras diferentes de iniciar un programa en Scratch

# %% [markdown]
# ### Zona de Ejecución
# >
# > En este espacio se observa el resultado esperado de la programación de los personajes y el escenario, como movimientos, mensajes, sonidos y todos los demas comportamientos
# > ![1.PNG](attachment:1.PNG)
#
# ### Ubicacion de los personajes en el Escenario
# > Como se observa en la imagen anterior, la posicion actual del personaje se muestra en las cajas de coordenadas (encerradas en rojo en la imagen), que corresponde a la ubicacion tradicional por plano cartesiano.

# %% [markdown]
# ## Desplazando el personaje a un Lugar especifico
# El personaje puede ser llevado a cualquier parte visible del escenario, una vez determinada la coordenada del lugar de destino, el comando usado para esto es:
# > ![3-2.PNG](attachment:3-2.PNG)
# > El cual se encuentra ubicado en la categoría __movimiento__.
# >
# > Si modificamos los valores de X e Y el personaje actual debe dirigirse a esa ubicacion en un movimiento suave.

# %% [markdown]
# ## Ejemplo Guiado

# %% [markdown]
# 1. En la categoria Eventos, Seleccione el comando:
# > ![4.PNG](attachment:4.PNG)

# %% [markdown]
# 2. En la caregoria Movimiento, seleccine el comando y arrastrelo para que se junte al anterior:
# > ![3.PNG](attachment:3.PNG)
# >
# > Use estos mismos valores para el tiempo y las coordenadas x, y

# %% [markdown]
# 3. Luego dentro de la categoría control, seleccione:
# > ![6.PNG](attachment:6.PNG)
# > Cambie el valor a 0.2

# %% [markdown]
# 4. Nuevamente, dentro de la categoria Movimiento, seleccione __deslizar__ y cambie los valores por __183 y -92__, respectivamente.
# 5. Ejecute el codigo, haciendo clic en la bandera verde
# > El personaje debió desplazarse suavemente al punto especificado
# 6. Agrege los comandos necesarios, para que el personaje se desplace a las 4 esquinas del escenario y retorne al mismo punto de partida.
# 7. Descargue el ejemplo en el computador

# %% [markdown]
# ## Actividad
# Desarolle la actividad en un nuevo archivo
# ### Cambie el fondo del escenario
# > - Guarde la siguiente imagen en el computador
# >
# > ![7.png](attachment:7.png)
# >

# %% [markdown]
# > - En Scratch, cargue la imagen haciendo clic en el boton inferior derecho, observe la imagen:
# > ![8.PNG](attachment:8.PNG)

# %% [markdown]
# > El escenario ahora se debe ver de la siguiente forma:
# >
# > ![9.PNG](attachment:9.PNG)

# %% [markdown]
# ### Programando el movimiento
# > - Agregue los comandos necesarios para que el personaje se deslice suavemente a cada uno de los puntos del pentagono
# ### Contesta en tu cuaderno
# > 1. EL personaje cumplio con el objetivo
# > 2. Escriba el algoritmo que uso para cumplir con la actividad
# > 3. ¿Crees que existe una forma mas agil y rapida de lograr el mismo desplazamiento sin requerir de todas las instrucciones? (Justifica la respuesta)

# %% [markdown]
# ### Termina la actividad
# Agrega la extension Lapiz en Scratch, para esto haz clic en el ultimo boton de la linea de codigo, observa la imagen:
# >
# > ![10.PNG](attachment:10.PNG)

# %% [markdown]
# En la nueva ventana selecciona Lapiz:
# > ![11.PNG](attachment:11.PNG)

# %% [markdown]
# Modifica el codigo del pentagono para que el Personaje a medida que se desplace dibuje una linea.
